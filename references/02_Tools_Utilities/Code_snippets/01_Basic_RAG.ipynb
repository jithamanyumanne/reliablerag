# %% [markdown]
# ## Ollama Basic Code snippets with Langchain

# %% [markdown]
# ### Install Libraries

# %%
# !pip install -U langchain-ollama langchain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [langchain]/6 [langgraph]
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Let's do a simple chat with ChatOllama

# %%
from langchain_ollama import ChatOllama
from langchain_core.messages import HumanMessage

# Initialize the chat model
model = ChatOllama(
    model="gemma3:4b-it-q4_K_M",
    temperature=0,
    validate_model_on_init=True
)

messages = [
    HumanMessage(content="Explain quantum computing in one sentence.")
]

response = model.invoke(messages)
print(response.content)
# Out:
# Quantum computing utilizes the principles of quantum mechanics – like superposition and entanglement – to perform complex calculations far beyond the capabilities of traditional computers by manipulating qubits instead of bits.

# %% [markdown]
# ### Using Embedding model

# %%
from langchain_ollama import OllamaEmbeddings

embeddings = OllamaEmbeddings(model="embeddinggemma:300m-qat-q4_0")
vector = embeddings.embed_query("This is a test document.")
print(vector)
# Out:
# [-0.16343519, 0.023209957, 0.009397604, -0.0010061101, -0.0009061543, -0.022188693, -0.016159898, -0.0014102854, 0.011207549, 0.0020902506, 0.011120687, -0.048796292, 0.00028581076, 0.01650915, 0.05728058, 0.006596912, 0.043037377, 0.0815076, -0.045341767, -0.026610058, 0.008226165, 0.008317537, 0.010666792, -0.044907168, 0.004268935, 0.03490491, 0.052109446, -0.0021648314, 0.024994666, -0.008750223, 0.005398158, -0.020307876, 0.013780815, -0.010908381, 0.08054203, 0.029253298, -0.022312464, -0.020709984, -0.02149962, -0.020461014, -0.051646527, 0.051047385, 0.013382747, 0.011572241, 0.0060836426, -0.03866523, -0.039345413, -0.022167133, -0.018392906, 0.03055031, 0.03120565, 0.00015663382, -0.005075916, 0.062178455, 0.009866595, -0.014554298, -0.048284702, 0.021513864, -0.027899968, -0.028409163, -0.06765334, 0.032377604, -0.004414307, 0.02230665, 0.070154585, 0.037193295, -0.027255746, -0.02925108, 0.010884316, 0.1958174, -0.006983026, -0.009726624, -0.0037684725, -0.009640402, 0.17
# ...
